# %% [markdown]
# ## 4.8 Part 1 - Grouping Data and Aggregating Variables

# %% [markdown]
# ### 1. Importing libraries

# %% [markdown]
# ### 2. Importing data

# %% [markdown]
# ### 3. Grouping data

# %% [markdown]
# ### 4. Aggregating variables

# %% [markdown]
# #### 1. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 2. Importing data

# %%
path = r'C:\Users\Priya\OneDrive\Documents\CareerFoundry\Data Immersion\Achievement 4\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\Priya\\OneDrive\\Documents\\CareerFoundry\\Data Immersion\\Achievement 4\\Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_new_variables.pkl'))

# %%
#Creating a subset of a million rows
df = ords_prods_merge[:1000000]

# %%
#Checking the shape of df
df.shape
# Out:
# (1000000, 19)

# %%
#Checking the first ten rows of df
df.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
# 5   2398795        1    prior             2                   3
# 6   2398795        1    prior             2                   3
# 7   2398795        1    prior             2                   3
# 8   2398795        1    prior             2                   3
# 9   2398795        1    prior             2                   3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     7.0         196                  1
# 1                  8                     7.0       14084                  2
# ...

# %% [markdown]
# #### 3. Grouping data

# %%
#Using the groupby function
df.groupby('product_name')

# %%
#Calculate the mean of the order_number column grouped by the department_id column
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.798797
# 2                17.091743
# 3                17.912467
# 4                17.892140
# 5                15.214874
# 6                15.381555
# 7                17.692609
# 8                16.458105
# 9                15.954859
# 10               20.091818
# 11               16.482026
# 12               15.607370
# 13               16.480156
# 14               17.524609
# 15               15.689477
# 16               18.018867
# 17               16.144400
# 18               19.602850
# 19               17.630579
# 20               17.138542
# 21               21.956893

# %%
#Checking the mean of the order_number column grouped by department_id
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.798797
# 2     17.091743
# 3     17.912467
# 4     17.892140
# 5     15.214874
# 6     15.381555
# 7     17.692609
# 8     16.458105
# 9     15.954859
# 10    20.091818
# 11    16.482026
# 12    15.607370
# 13    16.480156
# 14    17.524609
# 15    15.689477
# 16    18.018867
# 17    16.144400
# 18    19.602850
# 19    17.630579
# 20    17.138542
# 21    21.956893
# Name: order_number, dtype: float64

# %%
#Checking the mean, minimum, and maximum of the order_number column grouped by department_id
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.798797   1  99
# 2                17.091743   1  98
# 3                17.912467   1  99
# 4                17.892140   1  99
# 5                15.214874   1  99
# 6                15.381555   1  99
# 7                17.692609   1  99
# 8                16.458105   1  91
# 9                15.954859   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.607370   1  99
# 13               16.480156   1  99
# 14               17.524609   1  99
# 15               15.689477   1  99
# 16               18.018867   1  99
# 17               16.144400   1  99
# 18               19.602850   1  99
# 19               17.630579   1  99
# 20               17.138542   1  99
# 21               21.956893   1  97

# %% [markdown]
# #### 4. Aggregating variables

# %%
#Creating the max_order column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_8360\1681540670.py:1: FutureWarning: The provided callable <function max at 0x0000029BD3E2EFC0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Viewing the first fifteen rows of ords_prods_merge
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# 5    2398795        1    prior             2                   3
# 6    2398795        1    prior             2                   3
# 7    2398795        1    prior             2                   3
# 8    2398795        1    prior             2                   3
# 9    2398795        1    prior             2                   3
# 10   2398795        1    prior             2                   3
# 11    473747        1    prior             3                   3
# 12    473747        1    prior             3                   3
# ...

# %%
#Viewing the first one hundred rows of ords_prods_merge
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# ..       ...      ...      ...           ...                 ...
# 95    738281        2    prior             4                   2
# 96   1673511        2    prior             5                   3
# 97   1673511        2    prior             5                   3
# 98   1673511        2    prior             5                   3
# 99   1673511        2    prior             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     7.0         196                  1
# ...

# %%
pd.options.display.max_rows = None

# %%
#Viewing the first one hundred rows of ords_prods_merge
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# 5    2398795        1    prior             2                   3
# 6    2398795        1    prior             2                   3
# 7    2398795        1    prior             2                   3
# 8    2398795        1    prior             2                   3
# 9    2398795        1    prior             2                   3
# 10   2398795        1    prior             2                   3
# 11    473747        1    prior             3                   3
# 12    473747        1    prior             3                   3
# ...

# %%
#Creating a loyalty flag
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Checking the frequency of the loyalty_flag column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15874128
# Loyal customer      10282763
# New customer         6242841
# Name: count, dtype: int64

# %%
#Checking the columns
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
#Checking for products with prices over $100
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge, price_range_loc, busiest_day, busiest_days, busiest_period_of_day, max_order, loyalty_flag]
# Index: []
#
# [0 rows x 21 columns]

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
#Checking the maximum price in the prices column
ords_prods_merge['prices'].max()
# Out:
# 25.0
