# %% [markdown]
# ## 4.9 Part 1 - Data Visualization

# %% [markdown]
# ### 1. Importing libraries

# %% [markdown]
# ### 2. Importing data

# %% [markdown]
# ### 3. Data wrangling and consistency checks

# %% [markdown]
# ### 4. Combining dataframes

# %% [markdown]
# ### 5. Exporting the merged dataframe

# %% [markdown]
# #### 1. Importing libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 2. Importing data

# %%
path = r'C:\Users\Priya\OneDrive\Documents\CareerFoundry\Data Immersion\Achievement 4\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\Priya\\OneDrive\\Documents\\CareerFoundry\\Data Immersion\\Achievement 4\\Instacart Basket Analysis'

# %%
df_customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# #### 3. Data Wrangling and Consistency Checks

# %%
#Viewing the customers dataframe
df_customers.head(15)
# Out:
#     user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0     26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1     33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2     65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3    125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4    130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# 5    133128    Cynthia     Noble  Female        Kentucky   43    1/1/2017
# 6    152052      Chris    Walton    Male         Montana   20    1/1/2017
# 7    168851     Joseph   Hickman    Male  South Carolina   30    1/1/2017
# 8     69965     Jeremy      Vang    Male           Texas   47    1/1/2017
# 9     82820      Shawn     Chung    Male        Virginia   26    1/1/2017
# 10    26441     Gloria  Stafford  Female          Nevada   19    1/1/2017
# 11    33835      Roger     Casey    Male        Nebraska   45    1/1/2017
# ...

# %%
#Checking the shape of the dataframe
df_customers.shape
# Out:
# (206209, 10)

# %%
#Renaming Surnam column
df_customers.rename(columns = {'Surnam' : 'Last Name'}, inplace = True)

# %%
#Renaming STATE column
df_customers.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
#Renaming n_dependants column
df_customers.rename(columns = {'n_dependants' : 'number_of_dependants'}, inplace = True)

# %%
#Renaming fam_status column
df_customers.rename(columns = {'fam_status' : 'family_status'}, inplace = True)

# %%
#Checking if the columns were renamed
df_customers.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %%
#Checking data statistics
df_customers.describe()
# Out:
#              user_id            Age  number_of_dependants         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %%
#Checking data types for each column
df_customers.dtypes
# Out:
# user_id                  int64
# First Name              object
# Last Name               object
# Gender                  object
# State                   object
# Age                      int64
# date_joined             object
# number_of_dependants     int64
# family_status           object
# income                   int64
# dtype: object

# %%
#Checking for mixed-type data
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)
# Out:
# C:\Users\Priya\AppData\Local\Temp\ipykernel_17548\3987622072.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\Priya\AppData\Local\Temp\ipykernel_17548\3987622072.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\Priya\AppData\Local\Temp\ipykernel_17548\3987622072.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
# First Name
# C:\Users\Priya\AppData\Local\Temp\ipykernel_17548\3987622072.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
#Converting First Name column from a mixed-type column to a string
df_customers['First Name'] = df_customers['First Name'].astype('str')

# %%
#Checking for missing values
df_customers.isnull().sum()
# Out:
# user_id                 0
# First Name              0
# Last Name               0
# Gender                  0
# State                   0
# Age                     0
# date_joined             0
# number_of_dependants    0
# family_status           0
# income                  0
# dtype: int64

# %%
#Checking for duplicates
df_customers_duplicates = df_customers[df_customers.duplicated()]

# %%
#Viewing df_customers_duplicates
df_customers_duplicates
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, number_of_dependants, family_status, income]
# Index: []

# %% [markdown]
# #### 4. Combining Dataframes

# %%
#Importing prepared dataframe
ords_prods_merge_grouped = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_grouped.pkl'))

# %%
#Checking the shape of the prepared dataframe
ords_prods_merge_grouped.shape
# Out:
# (32399732, 25)

# %%
#Checking the ords_prods_merge_grouped dataframe
ords_prods_merge_grouped.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     7.0         196                  1
# 1                  8                     7.0       14084                  2
# 2                  8                     7.0       12427                  3
# 3                  8                     7.0       26088                  4
# 4                  8                     7.0       26405                  5
#
#    reordered  ...    price_range_loc     busiest_day    busiest_days  \
# ...

# %%
#Checking the df_customers dataframe
df_customers.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %%
#Checking data type of user_id column in ords_prods_merge_grouped dataframe
ords_prods_merge_grouped.dtypes['user_id']
# Out:
# dtype('int64')

# %%
#Checking data type of user_id column in df_customers dataframe
df_customers.dtypes['user_id']
# Out:
# dtype('int64')

# %%
#Testing the merge of the dataframes
pd.merge(ords_prods_merge_grouped,df_customers, on = ['user_id'], indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 #Testing the merge of the dataframes
# ----> 2 pd.merge(ords_prods_merge_grouped,df_customers, on = ['user_id'], indicator = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:884, in _MergeOperation.get_result(self, copy)
#     882 def get_result(self, copy: bool | None = True) -> DataFrame:
#     883     if self.indicator:
# ...

# %%
#Removing the _merge column from ords_prods_merge_grouped
ords_prods_merge_grouped = ords_prods_merge_grouped.drop(columns = ['_merge'])

# %%
#Merging the dataframes
ords_prods_custs = ords_prods_merge_grouped.merge(df_customers, on = 'user_id', indicator = True)

# %%
#Viewing the merged dataframe
ords_prods_custs.head(10)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
# 5   2398795        1    prior             2                   3
# 6   2398795        1    prior             2                   3
# 7   2398795        1    prior             2                   3
# 8   2398795        1    prior             2                   3
# 9   2398795        1    prior             2                   3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     7.0         196                  1
# 1                  8                     7.0       14084                  2
# ...

# %%
#Checking the shape of the merged dataframe
ords_prods_custs.shape
# Out:
# (32399732, 34)

# %%
#Checking the results of the merge
ords_prods_custs['_merge'].value_counts()
# Out:
# _merge
# both          32399732
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### 5. Exporting the Merged Dataframe

# %%
ords_prods_custs.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merged.pkl'))
