# %% [markdown]
# ## 4.6 Part 2 - Combining data

# %% [markdown]
# ### 1. Importing libraries

# %% [markdown]
# ### 2. Importing data

# %% [markdown]
# ### 3. Merging dataframes

# %% [markdown]
# ### 4. Confirming the results of the merge

# %% [markdown]
# ### 5. Exporting the merged dataframe

# %% [markdown]
# #### 1. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 2. Importing data

# %%
path = r'C:\Users\Priya\OneDrive\Documents\CareerFoundry\Data Immersion\Achievement 4\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\Priya\\OneDrive\\Documents\\CareerFoundry\\Data Immersion\\Achievement 4\\Instacart Basket Analysis'

# %%
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
#Checking the shape of the dataframe
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
#Checking the output of orders_products_combined
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     7.0         196                  1
# 1                  8                     7.0       14084                  2
# 2                  8                     7.0       12427                  3
# 3                  8                     7.0       26088                  4
# 4                  8                     7.0       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %%
#Checking the output of df_prods
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#Removing the Unnamed:0 column from df_prods
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
#Checking if the Unnamed:0 column was removed
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# #### 3. Merging dataframes

# %%
#Checking the shape of df_prods
df_prods.shape
# Out:
# (49670, 5)

# %%
#Looking at both dataframes, it is evident that the product_id column is present in both.
#Merging the dataframes using the inner join seems to be the most appropriate way to combine the dataframes since it will keep the data that is present in both dataframes.

# %%
#Testing the merge without overwriting
pd.merge(orders_products_combined,df_prods, on = ['product_id'], indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 #Testing the merge without overwriting
# ----> 2 pd.merge(orders_products_combined,df_prods, on = ['product_id'], indicator = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:884, in _MergeOperation.get_result(self, copy)
#     882 def get_result(self, copy: bool | None = True) -> DataFrame:
#     883     if self.indicator:
# ...

# %%
#Removing the _merge column from orders_products_combined
orders_products_combined = orders_products_combined.drop(columns = ['_merge'])

# %%
#Checking if the _merge column was removed
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     7.0         196                  1
# 1                  8                     7.0       14084                  2
# 2                  8                     7.0       12427                  3
# 3                  8                     7.0       26088                  4
# 4                  8                     7.0       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
#Checking the shape of orders_products_combined
orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
#Testing the merge without overwriting
pd.merge(orders_products_combined,df_prods, on = ['product_id'], indicator = True)
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32399727   2977660   206209    prior            13                   1
# 32399728   2977660   206209    prior            13                   1
# 32399729   2977660   206209    prior            13                   1
# 32399730   2977660   206209    prior            13                   1
# 32399731   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
#Merging the dataframes
df_ords_prods_merged = orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
#Checking the output
df_ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     7.0         196                  1
# 1                  8                     7.0       14084                  2
# 2                  8                     7.0       12427                  3
# 3                  8                     7.0       26088                  4
# 4                  8                     7.0       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
#Checking the shape of the dataframe
df_ords_prods_merged.shape
# Out:
# (32399732, 15)

# %% [markdown]
# #### 4. Confirming the results of the merge

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32399732
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### 5. Exporting the merged dataframe

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
